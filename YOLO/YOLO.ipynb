# %% [markdown]
# # YOLO Object Detection
#
# Este notebook implementa detección de objetos usando YOLO v3.
#
# **Nota importante**: El código ha sido actualizado para ser compatible con TensorFlow 2.x y versiones modernas de Keras.

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.12.0

# %%
# Verificar versiones de las librerías
import tensorflow as tf
import numpy as np

print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {tf.keras.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# 2025-11-11 15:58:33.897467: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-11 15:58:34.038164: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-11 15:58:37.673845: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-11 15:58:37.673845: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# TensorFlow version: 2.20.0
# Keras version: 3.12.0
# NumPy version: 2.2.6

# %% [markdown]
# ## Cambios Realizados para Compatibilidad
#
# El código original usaba `keras.backend` (TensorFlow 1.x), que ha sido deprecado. Se realizaron los siguientes cambios:
#
# ### Actualizaciones en `yolo_model.py`:
# 1. **Imports actualizados**: Se cambió de `keras.backend` a `tensorflow` y `numpy`
# 2. **Funciones reemplazadas**:
#    - `K.reshape()` → `np.array().reshape()`
#    - `K.variable()` → Eliminado (innecesario)
#    - `K.sigmoid()` → Función `_sigmoid()` personalizada con NumPy
#    - `K.exp()` → `np.exp()`
#    - `K.get_value()` → Eliminado (trabajamos directamente con arrays)
#
# 3. **Nueva función**: `_sigmoid(x)` implementada con NumPy para la activación sigmoid
#
# ### Requisitos:
# - TensorFlow >= 2.0
# - NumPy
# - OpenCV (cv2)

# %%
import os
import time
import cv2
import numpy as np
from model.yolo_model import YOLO

# %%
def process_image(img):
    """Resize, reduce and expand image.

    # Argument:
        img: original image.

    # Returns
        image: ndarray(64, 64, 3), processed image.
    """
    image = cv2.resize(img, (416, 416),
                       interpolation=cv2.INTER_CUBIC)
    image = np.array(image, dtype='float32')
    image /= 255.
    image = np.expand_dims(image, axis=0)

    return image

# %%
def get_classes(file):
    """Get classes name.

    # Argument:
        file: classes name for database.

    # Returns
        class_names: List, classes name.

    """
    with open(file) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]

    return class_names

# %%
def draw(image, boxes, scores, classes, all_classes):
    """Draw the boxes on the image.

    # Argument:
        image: original image.
        boxes: ndarray, boxes of objects.
        classes: ndarray, classes of objects.
        scores: ndarray, scores of objects.
        all_classes: all classes name.
    """
    for box, score, cl in zip(boxes, scores, classes):
        x, y, w, h = box

        top = max(0, np.floor(x + 0.5).astype(int))
        left = max(0, np.floor(y + 0.5).astype(int))
        right = min(image.shape[1], np.floor(x + w + 0.5).astype(int))
        bottom = min(image.shape[0], np.floor(y + h + 0.5).astype(int))

        cv2.rectangle(image, (top, left), (right, bottom), (255, 0, 0), 2)
        cv2.putText(image, '{0} {1:.2f}'.format(all_classes[cl], score),
                    (top, left - 6),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.6, (0, 0, 255), 1,
                    cv2.LINE_AA)

        print('class: {0}, score: {1:.2f}'.format(all_classes[cl], score))
        print('box coordinate x,y,w,h: {0}'.format(box))

    print()

# %%
def detect_image(image, yolo, all_classes):
    """Use yolo v3 to detect images.

    # Argument:
        image: original image.
        yolo: YOLO, yolo model.
        all_classes: all classes name.

    # Returns:
        image: processed image.
    """
    pimage = process_image(image)

    start = time.time()
    boxes, classes, scores = yolo.predict(pimage, image.shape)
    end = time.time()

    print('time: {0:.2f}s'.format(end - start))

    if boxes is not None:
        draw(image, boxes, scores, classes, all_classes)

    return image

# %%
def detect_video(video, yolo, all_classes):
    """Use yolo v3 to detect video.

    # Argument:
        video: video file.
        yolo: YOLO, yolo model.
        all_classes: all classes name.
    """
    video_path = os.path.join("videos", "test", video)
    camera = cv2.VideoCapture(video_path)
    cv2.namedWindow("detection", cv2.WINDOW_AUTOSIZE)

    # Prepare for saving the detected video
    sz = (int(camera.get(cv2.CAP_PROP_FRAME_WIDTH)),
        int(camera.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    fourcc = cv2.VideoWriter_fourcc(*'XVID')

    
    vout = cv2.VideoWriter()
    vout.open(os.path.join("videos", "res", video), fourcc, 20, sz, True)

    while True:
        res, frame = camera.read()

        if not res:
            break

        image = detect_image(frame, yolo, all_classes)
        cv2.imshow("detection", image)

        # Save the video frame by frame
        vout.write(image)

        if cv2.waitKey(110) & 0xff == 27:
                break

    vout.release()
    camera.release()

# %%
yolo = YOLO(0.3, 0.5)
file = 'data/coco_classes.txt'
all_classes = get_classes(file)
# Out:
# /home/brayan/anaconda3/envs/ComputerVision/lib/python3.13/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 2025-11-11 15:58:41.433883: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-11-11 15:58:42.695908: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 18874368 exceeds 10% of free system memory.
# 2025-11-11 15:58:42.718860: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 18874368 exceeds 10% of free system memory.
# 2025-11-11 15:58:42.728381: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 18874368 exceeds 10% of free system memory.
# 2025-11-11 15:58:42.820695: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 18874368 exceeds 10% of free system memory.
# 2025-11-11 15:58:42.853496: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 18874368 exceeds 10% of free system memory.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# Detectar imagenes

# %%
f = 'chicos.jpg'
path = 'imagenes/'+f
image = cv2.imread(path)
image = detect_image(image, yolo, all_classes)
cv2.imwrite('imagenes/res/' + f, image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# time: 3.94s
# class: person, score: 1.00
# box coordinate x,y,w,h: [202.6034832  177.55987644 150.48674941 336.68389561]
# class: person, score: 0.99
# box coordinate x,y,w,h: [544.07720566 158.26020241 198.30849675 217.17637491]
# class: person, score: 0.97
# box coordinate x,y,w,h: [ 95.17945051 186.38505936 156.90134168 343.45874087]
# class: person, score: 0.95
# box coordinate x,y,w,h: [430.2491188  178.5872519  142.43227243 322.74839099]
# class: person, score: 0.94
# box coordinate x,y,w,h: [337.45839596 112.98629344 109.77636163 437.34764594]
# True

# %%
# Detectar Videos

# %%
detect_video('video.mp4', yolo, all_classes)
# Out:
# OpenCV: FFMPEG: tag 0x6765706d/'mpeg' is not supported with codec id 2 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# time: 0.80s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 782ms/step
# time: 0.89s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 792ms/step
# time: 0.90s
# class: car, score: 0.32
# box coordinate x,y,w,h: [1458.15582275  760.99314451  135.93931537   74.96018206]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# time: 1.38s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 772ms/step
# time: 0.89s
# class: truck, score: 0.36
# box coordinate x,y,w,h: [1594.62238312  922.41105795  253.78778458  127.47312595]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step
# time: 1.41s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 800ms/step
# time: 0.89s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# time: 1.04s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step
# time: 1.10s
# class: truck, score: 0.33
# box coordinate x,y,w,h: [1601.1870575   912.93077946  249.27663418  129.62263845]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 799ms/step
# time: 0.91s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step
# time: 0.85s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 756ms/step
# time: 0.84s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.13s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 840ms/step
# time: 0.93s
# class: car, score: 0.34
# box coordinate x,y,w,h: [1273.58242035  722.95590162   86.61604368   73.14565033]
# class: car, score: 0.34
# box coordinate x,y,w,h: [1230.36289215  683.08737516   81.20429993   61.22827845]
# class: truck, score: 0.38
# box coordinate x,y,w,h: [1592.94250488  900.76054573  258.12584969  136.19678227]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 795ms/step
# time: 0.88s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 746ms/step
# time: 0.83s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 761ms/step
# time: 0.84s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 762ms/step
# time: 0.86s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.42s
# class: car, score: 0.44
# box coordinate x,y,w,h: [1249.69013214  717.52610207  124.78245075   73.79291605]
# class: car, score: 0.34
# box coordinate x,y,w,h: [1288.10829163  788.56494427  120.06410507   64.32550072]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 893ms/step
# time: 1.03s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# time: 0.79s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step
# time: 0.82s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 753ms/step
# time: 0.84s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 878ms/step
# time: 0.98s
# class: car, score: 0.36
# box coordinate x,y,w,h: [1436.61724091  724.28089142  127.83729865   71.9343832 ]
# class: car, score: 0.34
# box coordinate x,y,w,h: [1530.94345093  796.18645191  149.83515941   94.08661252]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 800ms/step
# time: 0.91s
# class: car, score: 0.42
# box coordinate x,y,w,h: [1433.10710907  725.76089144  124.46888814   70.62253293]
# class: car, score: 0.30
# box coordinate x,y,w,h: [1250.79483032  707.97230959  120.05347444   67.7393039 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step
# time: 0.87s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 894ms/step
# time: 1.40s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
# time: 0.81s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 913ms/step
# time: 1.01s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 920ms/step
# time: 1.44s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.11s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.22s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.51s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.12s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.46s
# class: car, score: 0.36
# box coordinate x,y,w,h: [683.23328018 962.82939434 164.72179413  85.57734558]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 892ms/step
# time: 0.99s
# class: car, score: 0.33
# box coordinate x,y,w,h: [685.40119171 958.48820686 160.23933759  87.99752341]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# time: 1.08s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 759ms/step
# time: 0.88s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# time: 1.08s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 895ms/step
# time: 0.99s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# time: 1.04s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# time: 1.05s
# class: car, score: 0.34
# box coordinate x,y,w,h: [979.06219482 599.24679995  72.30315575  70.1819507 ]
# class: car, score: 0.33
# box coordinate x,y,w,h: [863.0232811  606.95308685  82.37556751  63.23468324]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 809ms/step
# time: 0.91s
# class: car, score: 0.40
# box coordinate x,y,w,h: [860.58631897 605.08253574  85.09875958  64.57602966]
# class: car, score: 0.40
# box coordinate x,y,w,h: [1429.21268463  685.34281254  127.78320138   71.82331128]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.45s
# class: car, score: 0.44
# box coordinate x,y,w,h: [1430.1517868   684.79184389  128.75198639   72.9015005 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.28s
# class: car, score: 0.51
# box coordinate x,y,w,h: [1429.12181854  683.60815287  128.48960693   73.0941253 ]
# class: car, score: 0.49
# box coordinate x,y,w,h: [1501.65355682  752.75719643  150.80586901   88.08467116]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step
# time: 1.12s
# class: car, score: 0.44
# box coordinate x,y,w,h: [1502.97969818  751.54099703  151.51862933   90.01736111]
# class: car, score: 0.33
# box coordinate x,y,w,h: [1431.46980286  682.93358803  128.92841302   70.20756497]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.25s
# class: car, score: 0.38
# box coordinate x,y,w,h: [1428.64711761  680.74606419  130.21027042   70.84617872]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.18s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 887ms/step
# time: 1.52s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# time: 1.38s
# class: car, score: 0.34
# box coordinate x,y,w,h: [1322.42683411  806.54265404  142.23455237   74.97987092]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 818ms/step
# time: 0.91s
# class: car, score: 0.53
# box coordinate x,y,w,h: [1322.03407288  804.8296237   142.26085204   77.11147813]
# class: truck, score: 0.32
# box coordinate x,y,w,h: [1684.40803528  958.04229498  232.86494934  114.93197955]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 845ms/step
# time: 0.94s
# class: car, score: 0.47
# box coordinate x,y,w,h: [1320.32878876  804.39265966  142.26301267   76.78478259]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.20s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 732ms/step
# time: 1.42s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# time: 1.03s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.11s
# class: car, score: 0.49
# box coordinate x,y,w,h: [1502.28481293  714.47179556  143.59532696   94.27120802]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.40s
# class: car, score: 0.50
# box coordinate x,y,w,h: [1501.54735565  711.96568966  144.11236937   95.64006772]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 814ms/step
# time: 0.92s
# class: car, score: 0.48
# box coordinate x,y,w,h: [1501.31023407  710.38945198  145.66789957   95.19018514]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 851ms/step
# time: 0.95s
# class: car, score: 0.41
# box coordinate x,y,w,h: [1501.16477966  708.57908964  148.11107342   96.87796021]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 747ms/step
# time: 0.84s
# class: car, score: 0.31
# box coordinate x,y,w,h: [1502.67448425  710.87772131  148.16159386   94.77139472]
# class: car, score: 0.30
# box coordinate x,y,w,h: [1318.21266174  758.50261688  144.29756559   85.96965641]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 912ms/step
# time: 1.00s
# class: car, score: 0.57
# box coordinate x,y,w,h: [1502.26055145  714.64869261  147.09224912   87.64479673]
# class: car, score: 0.39
# box coordinate x,y,w,h: [1319.63768005  758.82261515  144.59649407   85.07197686]
# class: car, score: 0.34
# box coordinate x,y,w,h: [1303.35811615  982.19022274  168.64744553   83.15622104]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.21s
# class: car, score: 0.53
# box coordinate x,y,w,h: [1320.55423737  765.11449814  139.95596711   77.86633871]
# class: car, score: 0.43
# box coordinate x,y,w,h: [1304.03629303  982.54910231  171.11816278   80.7682387 ]
# class: car, score: 0.32
# box coordinate x,y,w,h: [1503.27735901  712.07872868  146.56336867   88.60656116]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 815ms/step
# time: 0.91s
# class: car, score: 0.70
# box coordinate x,y,w,h: [1321.82064056  763.43622923  138.21166387   78.58149414]
# class: car, score: 0.35
# box coordinate x,y,w,h: [1503.51860046  708.73023748  145.48708815   90.5680797 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 778ms/step
# time: 0.87s
# class: car, score: 0.39
# box coordinate x,y,w,h: [1319.22397614  762.43812561  138.09837644   77.51003159]
# class: car, score: 0.35
# box coordinate x,y,w,h: [1500.6905365   690.3279233   145.94536708   96.97524424]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 784ms/step
# time: 0.89s
# class: car, score: 0.49
# box coordinate x,y,w,h: [1319.10392761  764.26966667  139.99088205   73.55890621]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step
# time: 0.97s
# class: car, score: 0.37
# box coordinate x,y,w,h: [712.15370178 839.98771906 142.93261501  84.8915099 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 873ms/step
# time: 0.96s
# class: car, score: 0.31
# box coordinate x,y,w,h: [1502.10502625  693.87635708  148.01627838   86.70390989]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.19s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.13s
# class: car, score: 0.30
# box coordinate x,y,w,h: [1498.06171417  670.02403021  146.46441579   98.57806395]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.18s
# class: car, score: 0.47
# box coordinate x,y,w,h: [1495.02811432  668.59153748  148.2307247    99.65921433]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.23s
# class: car, score: 0.42
# box coordinate x,y,w,h: [1494.24911499  669.6948266   146.23560768   97.86095102]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.19s
# class: car, score: 0.48
# box coordinate x,y,w,h: [1493.96038055  670.2564168   144.9450624    96.59270666]
# class: car, score: 0.33
# box coordinate x,y,w,h: [1315.87543488  742.10816145  142.51093048   73.84391774]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 832ms/step
# time: 0.94s
# class: car, score: 0.35
# box coordinate x,y,w,h: [1497.04742432  672.23273277  139.88372243   92.83691099]
# class: car, score: 0.32
# box coordinate x,y,w,h: [1315.50579071  739.81055975  141.51919567   75.48202222]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 909ms/step
# time: 1.01s
# class: car, score: 0.49
# box coordinate x,y,w,h: [1497.15568542  673.31876993  140.58213913   88.66584128]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 786ms/step
# time: 0.88s
# class: car, score: 0.45
# box coordinate x,y,w,h: [1496.13189697  671.70564651  144.00431101   88.92104191]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# time: 1.12s
# class: car, score: 0.48
# box coordinate x,y,w,h: [1496.69528961  672.87099123  142.47402741   89.785202  ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.37s
# class: car, score: 0.43
# box coordinate x,y,w,h: [712.29177475 802.52564907 146.28200659  80.71917315]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step
# time: 0.94s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.42s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# time: 1.04s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.16s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.59s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.12s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 719ms/step
# time: 1.37s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# time: 1.06s
# class: car, score: 0.39
# box coordinate x,y,w,h: [1316.0533905   702.80244827  127.867157     71.42250136]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 749ms/step
# time: 0.85s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# time: 1.17s
# class: car, score: 0.38
# box coordinate x,y,w,h: [1485.88142395  627.88751364  147.84655149   99.24975583]
# class: car, score: 0.36
# box coordinate x,y,w,h: [1313.253479    697.77813435  132.64839677   75.2446882 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 892ms/step
# time: 0.99s
# class: car, score: 0.54
# box coordinate x,y,w,h: [1484.23851013  628.63475561  152.54881052   99.03756318]
# class: car, score: 0.34
# box coordinate x,y,w,h: [717.66878128 760.51562548 134.66239654  79.64114053]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# time: 1.04s
# class: car, score: 0.67
# box coordinate x,y,w,h: [1485.50697327  628.68973017  151.53881027   99.85628799]
# class: car, score: 0.37
# box coordinate x,y,w,h: [1312.42137909  694.20298576  137.47999356   77.38180487]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.12s
# class: car, score: 0.63
# box coordinate x,y,w,h: [1487.35656738  628.59375     144.85110255   96.94882871]
# class: car, score: 0.46
# box coordinate x,y,w,h: [1312.81116486  676.84731245  141.15513077   85.58315401]
# class: car, score: 0.34
# box coordinate x,y,w,h: [717.3995018  759.66976404 137.33795533  78.87927567]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 815ms/step
# time: 0.92s
# class: car, score: 0.64
# box coordinate x,y,w,h: [1489.78752136  629.91680861  143.83055338   93.44938682]
# class: car, score: 0.43
# box coordinate x,y,w,h: [1311.80820465  681.06786489  139.98490856   78.32580947]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.11s
# class: car, score: 0.49
# box coordinate x,y,w,h: [1490.45070648  632.46115208  140.50282249   87.83868856]
# class: car, score: 0.49
# box coordinate x,y,w,h: [1308.15559387  681.70341969  142.45706925   74.98805681]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.14s
# class: car, score: 0.56
# box coordinate x,y,w,h: [1489.64618683  632.00867414  143.35998251   87.45766715]
# class: car, score: 0.43
# box coordinate x,y,w,h: [1308.27495575  676.85806274  143.94723608   76.51084694]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.17s
# class: car, score: 0.53
# box coordinate x,y,w,h: [1470.92903137  632.77451992  142.91941524   81.22178002]
# class: car, score: 0.49
# box coordinate x,y,w,h: [1306.56097412  681.0618782   144.14993515   70.51054988]
# class: car, score: 0.40
# box coordinate x,y,w,h: [ 45.06294608 909.41813707 292.43478848 160.80095224]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.47s
# class: car, score: 0.59
# box coordinate x,y,w,h: [1466.54491425  628.65496874  144.44581334   84.08393215]
# class: car, score: 0.41
# box coordinate x,y,w,h: [ 38.4131062  913.86650562 307.96798193 154.68015539]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.39s
# class: car, score: 0.51
# box coordinate x,y,w,h: [1302.92884827  848.14674139  167.88676115   76.55589072]
# class: car, score: 0.36
# box coordinate x,y,w,h: [595.93894958 910.5149889  252.65382693 143.06300007]
# class: car, score: 0.34
# box coordinate x,y,w,h: [1468.78108978  610.70036888  140.18702663   91.62696444]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# time: 1.02s
# class: car, score: 0.51
# box coordinate x,y,w,h: [1306.27120972  843.94723892  162.3488859    82.17268924]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 912ms/step
# time: 1.01s
# class: car, score: 0.42
# box coordinate x,y,w,h: [1304.76230621  840.32406807  165.25984361   83.99109697]
# class: car, score: 0.41
# box coordinate x,y,w,h: [ 40.60760021 912.81877041 269.97296443 158.65951731]
# class: car, score: 0.37
# box coordinate x,y,w,h: [1469.13848877  610.51220655  136.66752687   90.4558831 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.39s
# class: car, score: 0.55
# box coordinate x,y,w,h: [ 30.3124094  917.02715635 278.96773668 151.51700463]
# class: car, score: 0.40
# box coordinate x,y,w,h: [1470.29159546  613.69822025  135.03425965   85.73294166]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 720ms/step
# time: 0.83s
# class: car, score: 0.52
# box coordinate x,y,w,h: [ 17.41351426 929.72145081 295.79006415 147.73603076]
# class: car, score: 0.37
# box coordinate x,y,w,h: [935.36939621 987.27717161 313.40683057  89.69450676]
# class: car, score: 0.31
# box coordinate x,y,w,h: [715.13820648 721.1051774  140.41356518  76.67377473]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 999ms/step
# time: 1.10s
# class: car, score: 0.49
# box coordinate x,y,w,h: [ 18.208251   934.51183319 297.83829689 142.91774298]
# class: car, score: 0.48
# box coordinate x,y,w,h: [713.15151215 719.52449799 143.58722916  76.72902597]
# class: car, score: 0.36
# box coordinate x,y,w,h: [ 913.29620361 1007.86810398  350.13427294   71.89769971]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# time: 1.08s
# class: car, score: 0.37
# box coordinate x,y,w,h: [1309.78385925  661.81910992  133.25220906   71.51335768]
# class: car, score: 0.37
# box coordinate x,y,w,h: [1465.72872162  607.62217999  137.62740612   86.50762635]
# class: car, score: 0.33
# box coordinate x,y,w,h: [ 929.78816986 1004.5613265   311.39144787   77.80870939]
# class: car, score: 0.30
# box coordinate x,y,w,h: [713.05206299 722.07946301 142.64901968  75.65665941]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.36s
# class: car, score: 0.35
# box coordinate x,y,w,h: [1466.15089417  609.10662174  139.18935464   84.65518665]
# class: car, score: 0.30
# box coordinate x,y,w,h: [712.84263611 721.20888233 144.11030861  74.6825236 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# time: 1.43s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.43s
# class: car, score: 0.43
# box coordinate x,y,w,h: [1464.18331146  606.86631203  145.59941328   85.80614492]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.39s
# class: car, score: 0.57
# box coordinate x,y,w,h: [1467.95379639  592.13660717  140.38541354   95.44659586]
# class: car, score: 0.48
# box coordinate x,y,w,h: [1287.22629547  633.11421633  136.55179739   85.63468244]
# class: car, score: 0.34
# box coordinate x,y,w,h: [971.50726318 958.67546797 308.90893276 122.95947419]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step
# time: 0.84s
# class: car, score: 0.56
# box coordinate x,y,w,h: [1463.9655304   590.93914032  140.1666732    95.66875395]
# class: car, score: 0.51
# box coordinate x,y,w,h: [1287.45426178  635.78325033  136.85070771   82.09080181]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 845ms/step
# time: 0.97s
# class: car, score: 0.65
# box coordinate x,y,w,h: [1462.32559204  592.91249514  134.24044875   91.90196071]
# class: car, score: 0.44
# box coordinate x,y,w,h: [1287.78316498  636.88035965  136.21848959   80.75038633]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 794ms/step
# time: 0.89s
# class: car, score: 0.46
# box coordinate x,y,w,h: [928.83401871 942.89770603 317.11015298 133.02541467]
# class: car, score: 0.39
# box coordinate x,y,w,h: [1464.41654205  611.24708891  135.65305105   78.40950491]
# class: car, score: 0.34
# box coordinate x,y,w,h: [1289.0826416   638.51826668  133.92813893   74.34757099]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 906ms/step
# time: 1.00s
# class: car, score: 0.60
# box coordinate x,y,w,h: [1461.69284821  590.41565895  138.82637006   93.64083712]
# class: car, score: 0.31
# box coordinate x,y,w,h: [1291.939888    639.73343611  131.62180149   72.53593264]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 826ms/step
# time: 1.38s
# class: car, score: 0.53
# box coordinate x,y,w,h: [1289.39769745  641.26474142  133.35548318   69.6697018 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 873ms/step
# time: 1.01s
# class: car, score: 0.68
# box coordinate x,y,w,h: [1290.1166153   642.69369364  133.33585602   67.09305948]
# class: car, score: 0.52
# box coordinate x,y,w,h: [1465.22151947  590.11046648  136.79719145   90.74567804]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 740ms/step
# time: 0.86s
# class: car, score: 0.60
# box coordinate x,y,w,h: [1291.64188385  640.82829237  129.68891584   69.55872241]
# class: car, score: 0.52
# box coordinate x,y,w,h: [1465.84671021  591.86714172  136.91308434   88.10617516]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# time: 1.04s
# class: car, score: 0.49
# box coordinate x,y,w,h: [1463.1357193   587.83269167  139.51968477   90.709895  ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# time: 1.03s
# class: car, score: 0.58
# box coordinate x,y,w,h: [1462.5422287   590.73655844  135.34390954   86.3467557 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 885ms/step
# time: 1.00s
# class: car, score: 0.60
# box coordinate x,y,w,h: [1462.67623901  590.75896025  134.51445745   86.08586053]
# class: car, score: 0.39
# box coordinate x,y,w,h: [715.92155457 677.48235226 133.96883671  78.20947722]
# class: car, score: 0.30
# box coordinate x,y,w,h: [1291.23779297  635.23974895  128.09804403   71.57503662]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.11s
# class: car, score: 0.61
# box coordinate x,y,w,h: [1463.64429474  593.07297707  135.81960962   83.90184935]
# class: car, score: 0.37
# box coordinate x,y,w,h: [929.39048767 910.81129789 296.57635029 142.81241418]
# class: car, score: 0.36
# box coordinate x,y,w,h: [716.14488602 676.40243053 136.61027945  80.43326473]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# time: 1.04s
# class: car, score: 0.51
# box coordinate x,y,w,h: [921.58533096 903.61194849 311.87307798 151.8473357 ]
# class: car, score: 0.50
# box coordinate x,y,w,h: [714.93524551 674.99317646 137.30782463  80.26577419]
# class: car, score: 0.42
# box coordinate x,y,w,h: [1463.92375946  589.14435625  135.31525859   87.47526327]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.41s
# class: car, score: 0.58
# box coordinate x,y,w,h: [924.28064346 897.43851185 305.47478969 154.76066654]
# class: car, score: 0.45
# box coordinate x,y,w,h: [1463.41930389  590.18861532  135.33452263   85.39286397]
# class: car, score: 0.40
# box coordinate x,y,w,h: [1282.51728058  618.01198483  129.41864738   74.96974888]
# class: car, score: 0.32
# box coordinate x,y,w,h: [715.6019783  677.23612547 136.37743152  77.74647584]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 843ms/step
# time: 0.96s
# class: car, score: 0.48
# box coordinate x,y,w,h: [1463.78997803  589.2181921   134.54307208   83.54990567]
# class: car, score: 0.37
# box coordinate x,y,w,h: [924.92774963 895.52856445 302.86561599 152.35080541]
# class: car, score: 0.32
# box coordinate x,y,w,h: [1283.20907593  610.85113049  129.86582362   83.76069604]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 876ms/step
# time: 0.98s
# class: car, score: 0.45
# box coordinate x,y,w,h: [1387.30407715  517.6327908    82.56857652   69.82559499]
# class: car, score: 0.41
# box coordinate x,y,w,h: [1461.54968262  588.79886627  134.46060529   83.63430581]
# class: car, score: 0.35
# box coordinate x,y,w,h: [1284.23160553  613.08590412  130.34819621   80.23064602]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 831ms/step
# time: 0.93s
# class: car, score: 0.43
# box coordinate x,y,w,h: [1280.99006653  616.63852215  132.91873785   73.61255586]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# time: 1.04s
# class: car, score: 0.43
# box coordinate x,y,w,h: [1284.4921875   616.62191391  130.19395682   76.27314276]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 812ms/step
# time: 0.90s
# class: car, score: 0.50
# box coordinate x,y,w,h: [1459.26864624  569.34720755  134.79526575   94.15592926]
# class: car, score: 0.35
# box coordinate x,y,w,h: [1282.08034515  612.37413168  128.69807069   78.46653569]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 717ms/step
# time: 0.81s
# class: car, score: 0.46
# box coordinate x,y,w,h: [1457.38643646  569.43044186  134.51777101   93.15238117]
# class: car, score: 0.43
# box coordinate x,y,w,h: [1280.91007233  589.59361553  132.31452612   91.07592554]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 823ms/step
# time: 0.93s
# class: car, score: 0.54
# box coordinate x,y,w,h: [1281.80408478  591.30716085  130.2003479    89.31867001]
# class: car, score: 0.47
# box coordinate x,y,w,h: [1212.17731476  507.44685531  111.22285586   57.67669565]
# class: car, score: 0.37
# box coordinate x,y,w,h: [1461.41967773  571.17701054  132.84096452   90.02991757]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 798ms/step
# time: 0.91s
# class: car, score: 0.71
# box coordinate x,y,w,h: [1280.07831573  588.72902155  133.75832127   91.50889535]
# class: car, score: 0.41
# box coordinate x,y,w,h: [1305.82214355  762.05208063  156.58601541   79.93747707]
# class: car, score: 0.39
# box coordinate x,y,w,h: [1457.09129333  565.42965889  136.57654469   94.36198605]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 799ms/step
# time: 0.89s
# class: car, score: 0.53
# box coordinate x,y,w,h: [1279.43664551  590.2931571   134.33368234   87.74912775]
# class: car, score: 0.36
# box coordinate x,y,w,h: [1457.78503418  568.11311245  134.5676832    91.66402163]
# class: car, score: 0.32
# box coordinate x,y,w,h: [1313.17428589  696.98808432  148.15454006   72.62244688]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 750ms/step
# time: 0.84s
# class: car, score: 0.55
# box coordinate x,y,w,h: [1458.11027527  568.77789259  132.77252362   89.17632796]
# class: car, score: 0.48
# box coordinate x,y,w,h: [1282.1238327   591.09563112  132.15959677   85.57318857]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 753ms/step
# time: 0.84s
# class: car, score: 0.61
# box coordinate x,y,w,h: [1280.29621124  590.17432451  132.7129431    87.70384907]
# class: car, score: 0.49
# box coordinate x,y,w,h: [1462.31506348  573.70352268  130.3294224    83.24998869]
# class: car, score: 0.33
# box coordinate x,y,w,h: [604.7845459  967.60246038 324.75786869 103.82185922]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 751ms/step
# time: 0.84s
# class: car, score: 0.53
# box coordinate x,y,w,h: [1280.32997131  590.67714214  132.99211731   86.53696033]
# class: car, score: 0.45
# box coordinate x,y,w,h: [1462.86895752  573.37431908  130.85281051   84.46380041]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# time: 1.02s
# class: car, score: 0.65
# box coordinate x,y,w,h: [1282.6493454   590.92304707  130.2588118    86.19473295]
# class: car, score: 0.60
# box coordinate x,y,w,h: [600.22579193 962.59565592 318.95084711 106.98296273]
# class: car, score: 0.50
# box coordinate x,y,w,h: [1459.49180603  572.66067982  131.61476585   85.37521091]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step
# time: 0.85s
# class: car, score: 0.47
# box coordinate x,y,w,h: [1281.4774704   592.07628965  129.13444381   83.79266374]
# class: car, score: 0.33
# box coordinate x,y,w,h: [1459.66255188  571.85530901  130.17037153   83.23015747]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 748ms/step
# time: 0.85s
# class: car, score: 0.63
# box coordinate x,y,w,h: [1280.49007416  594.85437155  131.27935189   80.21609648]
# class: car, score: 0.37
# box coordinate x,y,w,h: [1456.51119232  567.00905085  134.39946331   87.60075661]
# class: truck, score: 0.34
# box coordinate x,y,w,h: [1689.63912964  950.14688015  247.0414666   127.63776922]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# time: 0.77s
# class: car, score: 0.46
# box coordinate x,y,w,h: [1280.73795319  595.38293839  127.90082821   79.89486058]
# class: car, score: 0.43
# box coordinate x,y,w,h: [610.27879715 945.98896265 314.81644887 126.72762143]
# class: truck, score: 0.48
# box coordinate x,y,w,h: [1692.66220093  948.09808016  241.46647618  129.58963181]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 735ms/step
# time: 0.84s
# class: car, score: 0.54
# box coordinate x,y,w,h: [610.60375214 948.21111917 305.10474058 124.29489241]
# class: car, score: 0.37
# box coordinate x,y,w,h: [1281.41658783  596.19757891  129.40589245   79.77104713]
# class: truck, score: 0.50
# box coordinate x,y,w,h: [1685.00621796  946.94103956  252.25331563  127.50288764]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# time: 0.78s
# class: car, score: 0.60
# box coordinate x,y,w,h: [1280.34713745  594.9864006   131.4073824    79.50345376]
# class: car, score: 0.34
# box coordinate x,y,w,h: [614.5365715  948.70885134 311.83395129 120.87650419]
# class: truck, score: 0.51
# box coordinate x,y,w,h: [1688.17016602  946.86237574  247.37319066  127.60178223]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 699ms/step
# time: 0.80s
# class: car, score: 0.78
# box coordinate x,y,w,h: [1280.82904816  599.40760374  128.73258618   73.02680876]
# class: truck, score: 0.43
# box coordinate x,y,w,h: [1695.82969666  946.32634163  237.92818858  125.96153302]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step
# time: 0.80s
# class: car, score: 0.68
# box coordinate x,y,w,h: [1281.1555481   594.12605524  129.54649632   78.82794654]
# class: car, score: 0.37
# box coordinate x,y,w,h: [1359.88872528  501.31049752  125.16399127   62.63747651]
# class: car, score: 0.35
# box coordinate x,y,w,h: [1434.69726562  571.05933666  129.38739098   77.38152015]
# class: truck, score: 0.41
# box coordinate x,y,w,h: [1700.49545288  944.24129963  233.56621082  127.75804154]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step
# time: 0.82s
# class: car, score: 0.74
# box coordinate x,y,w,h: [1282.30796814  595.0799346   129.49773706   75.86984148]
# class: car, score: 0.42
# box coordinate x,y,w,h: [1360.46619415  501.46138787  126.75180371   63.78543092]
# class: car, score: 0.33
# box coordinate x,y,w,h: [1457.89398193  565.75152397   88.7349877    84.85003882]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 720ms/step
# time: 0.81s
# class: car, score: 0.65
# box coordinate x,y,w,h: [1282.63835907  597.82151699  128.77442782   71.381579  ]
# class: car, score: 0.43
# box coordinate x,y,w,h: [1360.76797485  502.59763598  124.67648038   62.60417059]
# class: car, score: 0.42
# box coordinate x,y,w,h: [611.77654266 940.57461262 306.85220608 134.45747134]
# class: car, score: 0.36
# box coordinate x,y,w,h: [1448.11958313  548.41535568   92.90265303   96.32765169]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# time: 0.77s
# class: car, score: 0.76
# box coordinate x,y,w,h: [613.51816177 934.84271049 304.010933   139.97043062]
# class: car, score: 0.53
# box coordinate x,y,w,h: [1447.89482117  545.33008575   93.43253209   98.68197716]
# class: car, score: 0.53
# box coordinate x,y,w,h: [1283.671875    595.0563097   128.43393913   73.56598167]
# class: car, score: 0.50
# box coordinate x,y,w,h: [1363.93764496  503.36444736  122.11498068   59.14791108]
# class: truck, score: 0.38
# box coordinate x,y,w,h: [1688.38256836  941.49347305  242.32990705  128.08459842]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 781ms/step
# time: 0.86s
# class: car, score: 0.58
# box coordinate x,y,w,h: [1284.15664673  601.17560863  124.98475946   63.9444366 ]
# class: car, score: 0.51
# box coordinate x,y,w,h: [1448.84147644  546.93522692   91.33966299   95.91432122]
# class: car, score: 0.47
# box coordinate x,y,w,h: [617.55214691 937.39201069 299.42362712 137.1321516 ]
# class: truck, score: 0.38
# box coordinate x,y,w,h: [1694.56729889  939.14108992  233.20951664  130.08826891]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 762ms/step
# time: 0.86s
# class: car, score: 0.65
# box coordinate x,y,w,h: [1283.83506775  598.94398928  125.15060086   66.25543593]
# class: car, score: 0.57
# box coordinate x,y,w,h: [614.21756744 935.08990288 310.85029199 140.18617152]
# class: car, score: 0.49
# box coordinate x,y,w,h: [1447.35626221  547.03655005   93.76493014   96.70364891]
# class: truck, score: 0.41
# box coordinate x,y,w,h: [1681.88026428  920.71354151  257.67787126  141.25087955]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# time: 0.73s
# class: car, score: 0.63
# box coordinate x,y,w,h: [613.70418549 932.43496656 308.23392061 145.87612719]
# class: car, score: 0.54
# box coordinate x,y,w,h: [1282.73288727  597.50332117  126.78510272   67.66120334]
# class: car, score: 0.53
# box coordinate x,y,w,h: [1447.04246521  545.96647739   90.60836792   94.67616815]
# class: truck, score: 0.43
# box coordinate x,y,w,h: [1689.6339798   919.72535133  249.20539086  141.25302428]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 762ms/step
# time: 0.84s
# class: car, score: 0.71
# box coordinate x,y,w,h: [1284.02309418  601.244874    125.3620332    63.18669316]
# class: car, score: 0.64
# box coordinate x,y,w,h: [619.3560791  911.6433835  299.65391856 153.03478109]
# class: car, score: 0.51
# box coordinate x,y,w,h: [1433.592453    551.27203703  131.14628297   87.67821654]
# class: truck, score: 0.40
# box coordinate x,y,w,h: [1689.99103546  918.33611727  246.64419596  143.84119092]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 844ms/step
# time: 1.39s
# class: car, score: 0.73
# box coordinate x,y,w,h: [613.66447449 908.88493538 306.04316711 157.41200539]
# class: car, score: 0.67
# box coordinate x,y,w,h: [1282.16239929  598.18805695  125.1874313    65.38921158]
# class: car, score: 0.41
# box coordinate x,y,w,h: [1432.01740265  552.88451672  127.95632353   85.27302957]
# class: car, score: 0.38
# box coordinate x,y,w,h: [1358.83312225  501.12140179  122.6707055    58.79659023]
# class: truck, score: 0.43
# box coordinate x,y,w,h: [1684.4260025   921.76668406  253.20591578  137.99897295]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 855ms/step
# time: 0.94s
# class: car, score: 0.86
# box coordinate x,y,w,h: [1284.4549942   601.31362438  120.12724427   61.16947494]
# class: car, score: 0.73
# box coordinate x,y,w,h: [616.3643074  907.44304419 302.80435049 157.92590632]
# class: car, score: 0.41
# box coordinate x,y,w,h: [1430.49716949  551.33042336  130.82200802   85.30550979]
# class: car, score: 0.39
# box coordinate x,y,w,h: [1307.96207428  714.76791143  152.60515011   89.27108504]
# class: car, score: 0.35
# box coordinate x,y,w,h: [1356.7219162   500.15751243  124.49672204   60.05332452]
# class: truck, score: 0.56
# box coordinate x,y,w,h: [1687.6197052   921.7877984   246.65894949  137.11922748]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 829ms/step
# time: 0.92s
# class: car, score: 0.78
# box coordinate x,y,w,h: [614.43574905 906.84939623 302.91020063 158.66525517]
# class: car, score: 0.69
# box coordinate x,y,w,h: [1282.66628265  598.91463518  125.76867507   65.38481967]
# class: car, score: 0.33
# box coordinate x,y,w,h: [1358.57162476  500.42807221  123.64443816   59.30008332]
# class: car, score: 0.32
# box coordinate x,y,w,h: [1450.33275604  549.97492075   92.00827965   88.43741085]
# class: truck, score: 0.41
# box coordinate x,y,w,h: [1689.86755371  916.58124447  247.14455366  142.91866215]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 771ms/step
# time: 0.87s
# class: car, score: 0.72
# box coordinate x,y,w,h: [617.70858765 905.25262356 303.13059954 156.65127881]
# class: car, score: 0.57
# box coordinate x,y,w,h: [1282.01122284  595.95225334  126.05061815   66.83706161]
# class: car, score: 0.32
# box coordinate x,y,w,h: [1357.71743774  500.44439077  125.08729825   60.08263002]
# class: truck, score: 0.35
# box coordinate x,y,w,h: [1686.75361633  914.06059027  250.6283982   146.17613949]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 751ms/step
# time: 0.84s
# class: car, score: 0.69
# box coordinate x,y,w,h: [618.41789246 904.8107028  307.03456989 156.66565133]
# class: car, score: 0.38
# box coordinate x,y,w,h: [1449.27864075  550.40518999   86.78009914   86.39237296]
# class: truck, score: 0.38
# box coordinate x,y,w,h: [1691.34807587  913.10941458  241.82907178  143.96059977]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step
# time: 0.85s
# class: car, score: 0.71
# box coordinate x,y,w,h: [617.28326797 905.68830013 311.32315526 157.21847782]
# class: car, score: 0.64
# box coordinate x,y,w,h: [1449.55535889  545.34205914   93.18072686   94.06854877]
# class: car, score: 0.30
# box coordinate x,y,w,h: [1281.8567276   575.79970121  126.38465221   78.8679293 ]
# class: truck, score: 0.47
# box coordinate x,y,w,h: [1683.95061493  910.53410769  251.54847237  145.79783042]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 734ms/step
# time: 0.82s
# class: car, score: 0.67
# box coordinate x,y,w,h: [616.53905869 903.53695393 299.08942993 158.91715019]
# class: car, score: 0.56
# box coordinate x,y,w,h: [1452.25330353  544.53128099   90.02465762   95.93618638]
# class: car, score: 0.37
# box coordinate x,y,w,h: [1281.06948853  575.33795357  126.07840666   81.38777575]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step
# time: 1.06s
# class: car, score: 0.72
# box coordinate x,y,w,h: [616.69527054 904.41989422 296.05146591 155.81579289]
# class: car, score: 0.48
# box coordinate x,y,w,h: [1450.63865662  546.92821026   88.45650893   91.01961679]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step
# time: 0.83s
# class: car, score: 0.72
# box coordinate x,y,w,h: [620.11568069 902.26835489 289.21517702 155.66768079]
# class: car, score: 0.60
# box coordinate x,y,w,h: [1280.21381378  580.2987957   126.66498844   71.3428348 ]
# class: car, score: 0.49
# box coordinate x,y,w,h: [1450.40828705  549.41777229   88.79992852   86.97834072]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step
# time: 0.85s
# class: car, score: 0.75
# box coordinate x,y,w,h: [620.40361404 895.5685401  293.17266941 158.14036595]
# class: car, score: 0.65
# box coordinate x,y,w,h: [1429.57775116  551.70043945  129.8365372    80.7930384 ]
# class: car, score: 0.61
# box coordinate x,y,w,h: [1281.41349792  579.25981522  124.85415074   72.26780541]
# class: truck, score: 0.40
# box coordinate x,y,w,h: [1688.03661346  902.26455688  244.94878567  153.60216114]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step
# time: 0.82s
# class: car, score: 0.79
# box coordinate x,y,w,h: [620.41339874 895.36943436 292.30782289 159.35680706]
# class: car, score: 0.53
# box coordinate x,y,w,h: [1429.50805664  553.40716124  128.46353421   79.57897755]
# class: car, score: 0.42
# box coordinate x,y,w,h: [425.33011436 552.79922247 120.05191299  83.97549394]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 747ms/step
# time: 0.84s
# class: car, score: 0.73
# box coordinate x,y,w,h: [621.62567139 893.69470596 288.00289778 159.70925396]
# class: car, score: 0.54
# box coordinate x,y,w,h: [1431.69834137  551.8668437   128.94668753   82.26605116]
# class: car, score: 0.52
# box coordinate x,y,w,h: [1282.59475708  579.95845556  122.78983024   69.26809465]
# class: truck, score: 0.31
# box coordinate x,y,w,h: [1675.7913208   897.6884079   258.44309312  153.66366213]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step
# time: 0.82s
# class: car, score: 0.82
# box coordinate x,y,w,h: [1280.82401276  583.6639595   122.33075243   63.21246805]
# class: car, score: 0.69
# box coordinate x,y,w,h: [621.03292465 890.84581375 287.48872464 160.62930375]
# class: car, score: 0.45
# box coordinate x,y,w,h: [1451.81430817  548.22654963   90.95843388   87.82761888]
# class: car, score: 0.35
# box coordinate x,y,w,h: [403.65569115 553.20419312 132.62054471  84.60441986]
# class: truck, score: 0.37
# box coordinate x,y,w,h: [1682.29740143  898.4768486   252.36752327  150.19377241]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 756ms/step
# time: 0.85s
# class: car, score: 0.72
# box coordinate x,y,w,h: [1282.38578796  581.91893578  121.12295536   66.87992011]
# class: car, score: 0.65
# box coordinate x,y,w,h: [620.80793381 890.87780714 287.27688789 159.90832442]
# class: car, score: 0.52
# box coordinate x,y,w,h: [1677.03025818  898.58544588  258.49334038  150.55393479]
# class: car, score: 0.43
# box coordinate x,y,w,h: [1431.26895905  551.99558973  131.75885576   80.92280264]
# class: car, score: 0.33
# box coordinate x,y,w,h: [402.4892807  554.84499693 130.4355017   79.51781823]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 758ms/step
# time: 0.87s
# class: car, score: 0.76
# box coordinate x,y,w,h: [622.83468246 889.18608427 291.50239981 160.47704145]
# class: car, score: 0.67
# box coordinate x,y,w,h: [1283.36585999  580.95784664  117.75786748   64.34069089]
# class: car, score: 0.44
# box coordinate x,y,w,h: [1673.63891602  892.58890629  263.06660909  154.94923615]
# class: car, score: 0.34
# box coordinate x,y,w,h: [1429.41993713  551.95104361  129.70732652   79.76128812]
# class: truck, score: 0.38
# box coordinate x,y,w,h: [1678.53961945  821.4359951   261.22114475  243.68111563]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 820ms/step
# time: 0.92s
# class: car, score: 0.88
# box coordinate x,y,w,h: [622.34390259 888.11871529 295.54275073 161.19742193]
# class: car, score: 0.63
# box coordinate x,y,w,h: [1280.84575653  579.67939854  121.07308855   62.85530675]
# class: car, score: 0.43
# box coordinate x,y,w,h: [402.32940674 555.60968399 129.68605619  79.75715246]
# class: car, score: 0.35
# box coordinate x,y,w,h: [1429.43332672  552.50252724  126.93376807   77.04787016]
# class: truck, score: 0.45
# box coordinate x,y,w,h: [1675.95932007  891.94974661  253.46685703  154.05965831]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step
# time: 0.83s
# class: car, score: 0.87
# box coordinate x,y,w,h: [616.88392639 888.34769011 296.90880775 158.155017  ]
# class: car, score: 0.60
# box coordinate x,y,w,h: [1281.5694809   580.20526171  119.3951019    63.29330199]
# class: car, score: 0.49
# box coordinate x,y,w,h: [1428.41846466  553.92021418  128.15446533   75.50680057]
# class: truck, score: 0.40
# box coordinate x,y,w,h: [1671.79206848  893.60690117  259.47624922  151.4696394 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 900ms/step
# time: 1.00s
# class: car, score: 0.81
# box coordinate x,y,w,h: [617.79636383 887.98218012 294.07534636 154.9719787 ]
# class: car, score: 0.52
# box coordinate x,y,w,h: [1282.90729523  580.26487112  116.58423185   62.55457118]
# class: car, score: 0.51
# box coordinate x,y,w,h: [399.50958252 563.51855278 132.47980466  88.81810606]
# class: car, score: 0.47
# box coordinate x,y,w,h: [1427.76741028  554.20744658  130.06216792   75.52414755]
# class: car, score: 0.37
# box coordinate x,y,w,h: [942.00857162 400.88173628  73.66845791  56.82727173]
# class: truck, score: 0.34
# box coordinate x,y,w,h: [1666.85657501  894.6128583   266.11806448  149.44344919]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step
# time: 0.68s
# class: car, score: 0.66
# box coordinate x,y,w,h: [1281.25797272  579.13473845  116.47561064   62.45796338]
# class: car, score: 0.63
# box coordinate x,y,w,h: [616.97605133 892.11331844 290.44874228 147.29201478]
# class: car, score: 0.42
# box coordinate x,y,w,h: [941.05384827 400.11598706  75.1636065   57.52049484]
# class: car, score: 0.38
# box coordinate x,y,w,h: [1429.243927    554.11391258  128.72658546   75.09615334]
# class: car, score: 0.32
# box coordinate x,y,w,h: [398.83672714 562.66496658 131.2026044   90.95858251]
# class: truck, score: 0.52
# box coordinate x,y,w,h: [1662.13382721  892.49807596  269.8484208   150.95135151]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# time: 1.37s
# class: car, score: 0.58
# box coordinate x,y,w,h: [1279.49008942  577.62326002  117.00387377   63.94116224]
# class: car, score: 0.40
# box coordinate x,y,w,h: [939.94588852 399.36864853  75.00948099  58.04032861]
# class: car, score: 0.37
# box coordinate x,y,w,h: [1670.40035248  870.10270357  262.93142245  160.47140108]
# class: car, score: 0.33
# box coordinate x,y,w,h: [1429.5059967   549.58295345  128.96146692   80.17819934]
# class: car, score: 0.32
# box coordinate x,y,w,h: [620.28282166 893.58900547 289.43052732 147.82829617]
# class: truck, score: 0.53
# box coordinate x,y,w,h: [1665.42068481  889.43295479  263.22594716  152.79295519]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 882ms/step
# time: 0.96s
# class: car, score: 0.63
# box coordinate x,y,w,h: [1670.99292755  873.20213556  261.86645673  154.41189632]
# class: car, score: 0.48
# box coordinate x,y,w,h: [1281.6897583   578.5885334   115.06213683   62.1862913 ]
# class: car, score: 0.45
# box coordinate x,y,w,h: [624.51936722 900.07580996 280.17871967 141.98696951]
# class: car, score: 0.33
# box coordinate x,y,w,h: [1428.98117065  547.69585848  130.51545382   83.20177021]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 794ms/step
# time: 0.89s
# class: car, score: 0.52
# box coordinate x,y,w,h: [1670.00782013  872.69442558  261.45003209  153.95068068]
# class: car, score: 0.47
# box coordinate x,y,w,h: [625.09786606 892.66943693 283.98521442 149.5883999 ]
# class: car, score: 0.38
# box coordinate x,y,w,h: [1280.48904419  575.5089283   118.81842448   65.19778975]
# class: car, score: 0.31
# box coordinate x,y,w,h: [657.65247345 782.67706633 144.89461459  75.51176906]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 718ms/step
# time: 0.80s
# class: car, score: 0.56
# box coordinate x,y,w,h: [1666.85668945  871.25684738  262.69666232  156.65774087]
# class: car, score: 0.54
# box coordinate x,y,w,h: [625.92710495 897.9446125  278.62233364 141.65666631]
# class: car, score: 0.43
# box coordinate x,y,w,h: [658.66333008 782.24930763 143.96916004  74.69468143]
# class: car, score: 0.38
# box coordinate x,y,w,h: [1274.70645905  552.73871183  126.5111031    81.82165669]
# class: car, score: 0.35
# box coordinate x,y,w,h: [1315.77404022  641.53897047  137.47566324   66.23433056]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 747ms/step
# time: 1.38s
# class: car, score: 0.66
# box coordinate x,y,w,h: [623.68469238 899.62680817 273.67048777 137.71783154]
# class: car, score: 0.57
# box coordinate x,y,w,h: [1280.08243561  576.41851902  118.18998291   64.59206907]
# class: car, score: 0.48
# box coordinate x,y,w,h: [1672.14797974  873.9277482   254.45026049  150.70671239]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 886ms/step
# time: 0.97s
# class: car, score: 0.68
# box coordinate x,y,w,h: [1670.66734314  871.47185326  255.48548038  154.01876907]
# class: car, score: 0.49
# box coordinate x,y,w,h: [1279.17709351  579.7746706   119.57030296   60.10424079]
# class: car, score: 0.49
# box coordinate x,y,w,h: [624.55541611 900.11031389 271.1888084  134.70646957]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 740ms/step
# time: 0.82s
# class: car, score: 0.70
# box coordinate x,y,w,h: [1673.98738861  871.74917221  250.1402015   151.67405777]
# class: car, score: 0.57
# box coordinate x,y,w,h: [1278.26580048  580.70711374  120.94394143   57.4963497 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step
# time: 0.85s
# class: car, score: 0.66
# box coordinate x,y,w,h: [1279.41318512  579.48524952  118.46964735   57.33836903]
# class: car, score: 0.61
# box coordinate x,y,w,h: [1670.81668854  870.45978069  253.00487555  152.36790759]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 722ms/step
# time: 0.82s
# class: car, score: 0.40
# box coordinate x,y,w,h: [1667.60902405  869.45008993  257.42279731  151.8028951 ]
# class: car, score: 0.39
# box coordinate x,y,w,h: [1263.03703308  564.48569298  113.431003     62.10984927]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 758ms/step
# time: 0.85s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 749ms/step
# time: 0.84s
# class: car, score: 0.30
# box coordinate x,y,w,h: [1310.19779205  673.03385496  147.49102923   91.24391435]
# class: truck, score: 0.35
# box coordinate x,y,w,h: [1667.15240479  864.8315835   257.46376606  154.10029688]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step
# time: 0.93s
# class: truck, score: 0.42
# box coordinate x,y,w,h: [1669.72320557  866.78157091  254.80782454  152.01855245]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 856ms/step
# time: 0.94s
# class: car, score: 0.31
# box coordinate x,y,w,h: [616.77932739 853.32767487 298.70017565 149.47170678]
# class: truck, score: 0.32
# box coordinate x,y,w,h: [1672.43156433  811.74444437  252.95090125  229.37482367]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 825ms/step
# time: 1.38s
# class: car, score: 0.43
# box coordinate x,y,w,h: [615.44219971 853.93838167 300.95280867 146.78659531]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step
# time: 1.38s
# class: car, score: 0.35
# box coordinate x,y,w,h: [617.91418076 854.26726341 299.71798127 146.63819075]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 749ms/step
# time: 0.83s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 746ms/step
# time: 0.84s
# class: car, score: 0.56
# box coordinate x,y,w,h: [1258.27274323  564.85944271  120.28890967   60.83336918]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step
# time: 0.83s
# class: car, score: 0.41
# box coordinate x,y,w,h: [624.55055237 855.23697853 284.50682402 143.04244404]
# class: truck, score: 0.34
# box coordinate x,y,w,h: [1662.70694733  856.21184349  260.7992396   146.1026057 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 752ms/step
# time: 0.84s
# class: car, score: 0.53
# box coordinate x,y,w,h: [1259.88178253  564.72670555  121.03644875   58.74117528]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 639ms/step
# time: 0.75s
# class: car, score: 0.51
# box coordinate x,y,w,h: [1261.96105957  565.85870504  115.60093073   56.88999194]
# class: car, score: 0.31
# box coordinate x,y,w,h: [1426.8075943   535.27318597  126.75462704   74.46418085]
# class: truck, score: 0.33
# box coordinate x,y,w,h: [1662.02190399  851.36745214  261.70582239  147.6482498 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 751ms/step
# time: 0.84s
# class: car, score: 0.33
# box coordinate x,y,w,h: [1663.03287506  850.99750042  262.88891866  149.74940826]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 732ms/step
# time: 0.82s
# class: truck, score: 0.36
# box coordinate x,y,w,h: [ 45.22110701 774.16251183 269.54147651 243.15201477]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 747ms/step
# time: 0.84s
# class: truck, score: 0.60
# box coordinate x,y,w,h: [ 39.09106135 767.14907169 279.33485104 258.12256926]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 741ms/step
# time: 0.82s
# class: truck, score: 0.48
# box coordinate x,y,w,h: [ 37.93773651 777.56797314 277.19092424 244.87077771]
# class: truck, score: 0.44
# box coordinate x,y,w,h: [1663.90090942  831.18477345  261.57126683  149.87128216]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 761ms/step
# time: 0.85s
# class: car, score: 0.39
# box coordinate x,y,w,h: [1669.47635651  834.33312893  251.39784996  143.46481768]
# class: truck, score: 0.63
# box coordinate x,y,w,h: [ 33.53272676 770.51011562 287.31547209 259.48799676]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step
# time: 0.96s
# class: car, score: 0.35
# box coordinate x,y,w,h: [681.90776825 739.41839933 140.22885919  74.95897909]
# class: car, score: 0.33
# box coordinate x,y,w,h: [1486.06155396  580.79717159  217.01435896  107.75361915]
# class: car, score: 0.31
# box coordinate x,y,w,h: [1663.30226898  832.01962709  261.24796849  146.2533082 ]
# class: truck, score: 0.42
# box coordinate x,y,w,h: [ 30.59925199 775.40780783 290.73673065 252.30017647]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 748ms/step
# time: 0.86s
# class: car, score: 0.34
# box coordinate x,y,w,h: [1520.84209442  587.90498257  150.59139545   94.98241999]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step
# time: 0.98s
# class: car, score: 0.39
# box coordinate x,y,w,h: [679.18733597 731.26150131 144.22433138  85.90041085]
# class: truck, score: 0.55
# box coordinate x,y,w,h: [ 15.00973284 816.66215658 303.13615542 238.66899312]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# time: 0.71s
# class: car, score: 0.37
# box coordinate x,y,w,h: [936.63539886 672.54886866 138.41336434  90.52128485]
# class: car, score: 0.33
# box coordinate x,y,w,h: [679.38943863 732.40148306 143.4246287   81.9366792 ]
# class: car, score: 0.33
# box coordinate x,y,w,h: [ -1.87531918 818.42642784 274.99875949 242.30351621]
# class: truck, score: 0.55
# box coordinate x,y,w,h: [ 14.82606143 816.20150328 307.11396823 242.88426945]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step
# time: 0.80s
# class: car, score: 0.38
# box coordinate x,y,w,h: [ -2.64765054 826.81133509 274.6886213  231.74602709]
# class: car, score: 0.37
# box coordinate x,y,w,h: [914.81357574 673.81946325 141.78385377  83.11837373]
# class: truck, score: 0.53
# ...
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 718ms/step
# time: 0.81s
# class: car, score: 0.62
# box coordinate x,y,w,h: [626.77757263 908.20534945 281.8444694  164.82720587]
# class: car, score: 0.41
# box coordinate x,y,w,h: [1652.18891144  946.31990433  283.25922159  132.3548784 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# time: 0.78s
# class: car, score: 0.66
# box coordinate x,y,w,h: [626.26499176 907.27631807 274.89245488 163.87541678]
# class: car, score: 0.55
# box coordinate x,y,w,h: [1652.88619995  946.58827543  284.97590083  132.33699632]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 713ms/step
# time: 0.80s
# class: car, score: 0.68
# box coordinate x,y,w,h: [1658.11969757  947.60543346  276.89385157  132.69913632]
# class: car, score: 0.68
# box coordinate x,y,w,h: [630.27769089 907.84614801 275.11902809 163.6151378 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 740ms/step
# time: 0.83s
# class: car, score: 0.69
# box coordinate x,y,w,h: [628.66333008 906.61784649 277.70278821 165.23030475]
# class: car, score: 0.57
# box coordinate x,y,w,h: [1661.22917175  946.75242662  277.22840694  133.9144215 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step
# time: 0.78s
# class: car, score: 0.59
# box coordinate x,y,w,h: [628.71809006 904.60406542 280.31777804 162.63752832]
# class: car, score: 0.54
# box coordinate x,y,w,h: [1664.15565491  947.49902487  271.4434389   132.77273975]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# time: 0.79s
# class: car, score: 0.58
# box coordinate x,y,w,h: [632.36978531 902.98798084 276.96043858 164.28755419]
# class: car, score: 0.40
# box coordinate x,y,w,h: [1665.27580261  944.34461832  268.20156923  134.48377916]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 720ms/step
# time: 0.82s
# class: car, score: 0.63
# box coordinate x,y,w,h: [629.64363098 905.10160446 282.66643689 162.07864365]
# class: car, score: 0.36
# box coordinate x,y,w,h: [1664.69638824  944.23885345  268.36612646  133.22048812]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step
# time: 0.78s
# class: car, score: 0.44
# box coordinate x,y,w,h: [633.92166138 900.69018602 276.58281656 165.18475001]
# class: car, score: 0.42
# box coordinate x,y,w,h: [1663.07487488  942.33836889  269.21770334  133.72163205]
# class: truck, score: 0.53
# box coordinate x,y,w,h: [633.0843544 864.6579051 278.912136  226.0919603]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# time: 1.35s
# class: car, score: 0.76
# box coordinate x,y,w,h: [632.98931122 896.56226635 279.7436186  163.1217372 ]
# class: car, score: 0.39
# box coordinate x,y,w,h: [1661.44420624  942.24406242  274.67403449  134.38101291]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step
# time: 0.80s
# class: car, score: 0.79
# box coordinate x,y,w,h: [628.31989288 896.37661457 286.07799768 163.93381208]
# class: car, score: 0.40
# box coordinate x,y,w,h: [1662.27241516  938.87999296  273.92965519  137.19693932]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 822ms/step
# time: 0.95s
# class: car, score: 0.69
# box coordinate x,y,w,h: [630.54250717 896.46422625 276.52061297 162.59346375]
# class: car, score: 0.44
# box coordinate x,y,w,h: [1666.15184784  939.54361439  263.38931047  133.47200711]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step
# time: 0.73s
# class: car, score: 0.71
# box coordinate x,y,w,h: [634.1840744  894.78106499 273.85793429 163.93303218]
# class: car, score: 0.43
# box coordinate x,y,w,h: [1669.6628952   939.86226082  254.53641085  133.33814219]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# time: 0.79s
# class: car, score: 0.38
# box coordinate x,y,w,h: [1664.81666565  939.32783604  264.2302614   132.57415673]
# class: truck, score: 0.49
# box coordinate x,y,w,h: [639.91962433 862.9641223  265.85284792 221.69467607]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 812ms/step
# time: 1.43s
# class: car, score: 0.55
# box coordinate x,y,w,h: [633.59436035 891.59968615 275.25337898 166.67035543]
# class: car, score: 0.50
# box coordinate x,y,w,h: [1661.09893799  917.18396902  277.3429557   145.53100581]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# time: 0.79s
# class: car, score: 0.69
# box coordinate x,y,w,h: [1663.29837799  917.87333965  270.07647789  143.90799804]
# class: truck, score: 0.62
# box coordinate x,y,w,h: [640.06433487 858.20451021 267.13386407 229.44559019]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step
# time: 0.82s
# class: car, score: 0.67
# box coordinate x,y,w,h: [1664.05403137  917.83452272  266.85316526  142.39165605]
# class: car, score: 0.54
# box coordinate x,y,w,h: [636.10342026 892.48784065 275.59347758 166.4427767 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step
# time: 0.78s
# class: car, score: 0.70
# box coordinate x,y,w,h: [1668.28617096  916.75955772  263.50402979  144.82222641]
# class: car, score: 0.42
# box coordinate x,y,w,h: [638.99711609 889.77831602 277.25619133 168.95227054]
# class: truck, score: 0.50
# box coordinate x,y,w,h: [646.13639832 855.48030853 266.50704668 234.10332765]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 677ms/step
# time: 0.76s
# class: car, score: 0.62
# box coordinate x,y,w,h: [1671.2607193   917.20746517  255.26197727  143.79612362]
# class: truck, score: 0.52
# box coordinate x,y,w,h: [643.94731522 853.93896103 273.61599244 234.72253014]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 720ms/step
# time: 0.81s
# class: car, score: 0.61
# box coordinate x,y,w,h: [1665.37799835  918.51546049  264.5146889   142.64615539]
# class: truck, score: 0.52
# box coordinate x,y,w,h: [644.93740082 854.64989662 271.75011552 233.65409003]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step
# time: 0.82s
# class: car, score: 0.75
# box coordinate x,y,w,h: [1665.22476196  917.97041416  260.34870276  143.40823287]
# class: truck, score: 0.39
# box coordinate x,y,w,h: [641.46909714 853.6859107  270.69896001 229.60417498]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step
# time: 0.75s
# class: car, score: 0.76
# box coordinate x,y,w,h: [1668.10123444  918.52054596  258.20220984  141.43240217]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step
# time: 0.84s
# class: car, score: 0.77
# box coordinate x,y,w,h: [1668.43757629  919.42048073  255.72348118  140.68479469]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step
# time: 0.83s
# class: car, score: 0.76
# box coordinate x,y,w,h: [1664.91142273  916.62347317  263.32432674  146.62003013]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 713ms/step
# time: 0.80s
# class: car, score: 0.69
# box coordinate x,y,w,h: [1662.24403381  914.44360971  266.56524126  152.60515156]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 830ms/step
# time: 0.92s
# class: car, score: 0.70
# box coordinate x,y,w,h: [1661.53873444  913.21357012  267.4044013   153.05061593]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 825ms/step
# time: 0.95s
# class: car, score: 0.72
# box coordinate x,y,w,h: [1664.92538452  912.87451744  263.32679987  151.68021344]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# time: 0.80s
# class: car, score: 0.72
# box coordinate x,y,w,h: [1661.37886047  908.98844719  272.18655605  154.23542914]
# class: truck, score: 0.34
# box coordinate x,y,w,h: [645.88909149 828.76666546 254.65359367 234.0628528 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 685ms/step
# time: 0.77s
# class: car, score: 0.75
# box coordinate x,y,w,h: [1657.12314606  903.95338297  276.3442188   158.97886008]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step
# time: 0.87s
# class: car, score: 0.82
# box coordinate x,y,w,h: [1655.95733643  905.47670603  273.05346636  158.18755013]
# class: truck, score: 0.34
# box coordinate x,y,w,h: [650.06401062 825.60080051 253.13434179 236.03170166]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step
# time: 0.77s
# class: car, score: 0.73
# box coordinate x,y,w,h: [1657.57381439  905.94038486  268.80298431  155.16267912]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 750ms/step
# time: 0.84s
# class: car, score: 0.74
# box coordinate x,y,w,h: [1656.10404968  906.24371052  272.19078596  154.10429388]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 724ms/step
# time: 0.83s
# class: car, score: 0.75
# box coordinate x,y,w,h: [1656.78817749  904.87720013  272.04270491  154.20751973]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 669ms/step
# time: 0.76s
# class: car, score: 0.78
# box coordinate x,y,w,h: [1649.9874115   904.2348218   278.40609642  155.41680243]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 742ms/step
# time: 0.83s
# class: car, score: 0.82
# box coordinate x,y,w,h: [1648.61377716  899.30597305  279.4928769   156.08388484]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 742ms/step
# time: 0.85s
# class: car, score: 0.81
# box coordinate x,y,w,h: [1646.02558136  896.59187794  284.39688041  158.52377226]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 718ms/step
# time: 0.82s
# class: car, score: 0.77
# box coordinate x,y,w,h: [1615.68008423  900.98179579  286.19672519  147.79935617]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 727ms/step
# time: 1.37s
# class: car, score: 0.77
# box coordinate x,y,w,h: [1612.97870636  899.27397966  289.63124349  150.02165041]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step
# time: 0.82s
# class: car, score: 0.74
# box coordinate x,y,w,h: [1610.90869904  897.57775068  292.54258303  152.92218247]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 740ms/step
# time: 0.83s
# class: car, score: 0.71
# box coordinate x,y,w,h: [1609.0447998   896.68895245  295.28881953  153.52428217]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 862ms/step
# time: 1.39s
# class: car, score: 0.83
# box coordinate x,y,w,h: [1607.90588379  893.93314362  297.98344429  156.56437524]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 803ms/step
# time: 0.90s
# class: car, score: 0.68
# box coordinate x,y,w,h: [1613.6492157   898.04046392  284.78574239  150.67576692]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 770ms/step
# time: 0.86s
# class: car, score: 0.81
# box coordinate x,y,w,h: [1618.24012756  894.66062307  278.87104566  152.76648024]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 735ms/step
# time: 0.83s
# class: car, score: 0.78
# box coordinate x,y,w,h: [1623.77883911  895.56963444  272.74278953  149.03954256]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# time: 0.81s
# class: car, score: 0.76
# box coordinate x,y,w,h: [1624.50187683  892.21451283  270.5832828   151.79481753]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 813ms/step
# time: 0.92s
# class: car, score: 0.76
# box coordinate x,y,w,h: [1617.79781342  889.47904587  281.55233255  155.37350384]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 713ms/step
# time: 0.80s
# class: car, score: 0.84
# box coordinate x,y,w,h: [1618.24001312  892.15799332  280.14157149  151.53974719]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# time: 0.81s
# class: car, score: 0.82
# box coordinate x,y,w,h: [1614.49928284  887.63282776  285.77398979  156.16879687]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 677ms/step
# time: 0.77s
# class: car, score: 0.80
# box coordinate x,y,w,h: [1614.18399811  884.82609987  289.75305814  158.68175849]
# class: bus, score: 0.36
# box coordinate x,y,w,h: [196.75563812 426.78637147 271.43040116 254.1280263 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 717ms/step
# time: 0.82s
# class: car, score: 0.78
# box coordinate x,y,w,h: [1612.56134033  888.27321053  291.89864709  153.78496504]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step
# time: 0.83s
# class: car, score: 0.77
# box coordinate x,y,w,h: [1614.01199341  886.25749826  289.87255317  154.9064807 ]
# class: bus, score: 0.45
# box coordinate x,y,w,h: [199.6547842  423.51329327 266.60461004 260.59860584]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step
# time: 0.75s
# class: car, score: 0.73
# box coordinate x,y,w,h: [1614.93816376  870.14737844  286.66917911  155.93102368]
# class: bus, score: 0.45
# box coordinate x,y,w,h: [193.20981503 424.5022881  274.02354791 255.88615922]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 740ms/step
# time: 0.83s
# class: car, score: 0.66
# box coordinate x,y,w,h: [1619.45972443  871.14715576  278.10785349  152.84341218]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
# time: 0.84s
# class: car, score: 0.69
# box coordinate x,y,w,h: [1617.74105072  870.81988335  281.04887064  152.09877113]
# class: bus, score: 0.40
# box coordinate x,y,w,h: [191.34133816 427.10183144 274.31216405 254.7338047 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step
# time: 0.82s
# class: car, score: 0.77
# box coordinate x,y,w,h: [1616.82369232  870.66506624  281.5210005   152.02768846]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 790ms/step
# time: 0.98s
# class: car, score: 0.70
# box coordinate x,y,w,h: [1621.09325409  868.48204851  272.04524627  152.22007403]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 845ms/step
# time: 0.99s
# class: car, score: 0.82
# box coordinate x,y,w,h: [1623.9723587   867.74465561  269.2764616   153.16219788]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# time: 1.38s
# class: car, score: 0.81
# box coordinate x,y,w,h: [1621.78390503  866.74275398  273.03131048  152.72496429]
# class: bus, score: 0.55
# box coordinate x,y,w,h: [188.47532272 428.42353821 271.7404095  258.84004939]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# time: 0.79s
# class: car, score: 0.91
# box coordinate x,y,w,h: [1616.92440033  863.97754669  281.73010826  156.51682896]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step
# time: 1.40s
# class: car, score: 0.80
# box coordinate x,y,w,h: [1616.51504517  865.53350687  283.14300134  151.08531393]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 721ms/step
# time: 0.82s
# class: car, score: 0.77
# box coordinate x,y,w,h: [1612.32192993  863.03634882  288.51802606  152.31261798]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 732ms/step
# time: 0.82s
# class: car, score: 0.69
# box coordinate x,y,w,h: [1614.46231842  863.06544542  283.09792207  152.41147079]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step
# time: 0.78s
# class: car, score: 0.82
# box coordinate x,y,w,h: [1608.6428833   861.35511875  292.7603894   153.11133701]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 702ms/step
# time: 0.78s
# class: car, score: 0.75
# box coordinate x,y,w,h: [1610.6224823   859.03389215  285.18833454  153.7860374 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# time: 0.81s
# class: car, score: 0.59
# box coordinate x,y,w,h: [1606.84101105  859.9687171   287.10550822  151.5009609 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step
# time: 0.81s
# class: car, score: 0.79
# box coordinate x,y,w,h: [1607.85758972  856.80278778  285.45601295  154.20906561]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 861ms/step
# time: 0.95s
# class: car, score: 0.83
# box coordinate x,y,w,h: [1609.76909637  854.37193394  282.34602103  155.47384683]
# class: car, score: 0.34
# box coordinate x,y,w,h: [1544.28417206  592.94706345  140.17936459   88.78809585]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 741ms/step
# time: 0.83s
# class: car, score: 0.85
# box coordinate x,y,w,h: [1617.11174011  859.26705122  271.98352025  151.89942213]
# class: car, score: 0.51
# box coordinate x,y,w,h: [1543.7802887   593.66862059  140.1180592    86.88622758]
# class: bus, score: 0.40
# box coordinate x,y,w,h: [128.05625439 435.31685829 299.73641891 254.21960109]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# time: 0.80s
# class: car, score: 0.84
# box coordinate x,y,w,h: [1618.41751099  855.37550926  272.09312274  152.11847763]
# class: car, score: 0.59
# box coordinate x,y,w,h: [1541.49799347  591.93994761  143.06454915   89.48153374]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
# time: 0.82s
# class: car, score: 0.79
# box coordinate x,y,w,h: [1620.68344116  856.51690722  273.21776775  150.53580203]
# class: car, score: 0.52
# box coordinate x,y,w,h: [1541.08211517  590.82796812  139.94520939   89.3889833 ]
# class: bus, score: 0.31
# box coordinate x,y,w,h: [127.55142689 434.30491447 296.60760696 262.34692389]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 761ms/step
# time: 0.90s
# class: car, score: 0.71
# box coordinate x,y,w,h: [1614.32979584  853.67174864  275.2113357   152.1543532 ]
# class: car, score: 0.38
# box coordinate x,y,w,h: [1540.85586548  589.24046516  141.47944203   91.41065037]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 885ms/step
# time: 0.98s
# class: car, score: 0.72
# box coordinate x,y,w,h: [1616.67137146  854.67352152  271.80345902  151.58854689]
# class: car, score: 0.33
# box coordinate x,y,w,h: [1539.76593018  588.79333019  142.25691208   90.00607881]
# class: bus, score: 0.33
# box coordinate x,y,w,h: [129.10084248 432.25411892 293.57679661 267.69219966]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 810ms/step
# time: 0.91s
# class: car, score: 0.60
# box coordinate x,y,w,h: [1616.36100769  855.9649086   275.04768243  148.49312242]
# class: bus, score: 0.37
# box coordinate x,y,w,h: [123.91990185 428.2587111  300.73841132 273.69676608]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# time: 0.76s
# class: car, score: 0.50
# box coordinate x,y,w,h: [1614.81628418  854.7601676   274.35771209  147.83470252]
# class: bus, score: 0.61
# box coordinate x,y,w,h: [126.11346245 427.54491091 298.45584099 276.48700751]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step
# time: 0.82s
# class: car, score: 0.48
# box coordinate x,y,w,h: [1616.8932724   852.94993401  268.53155356  148.59331222]
# class: bus, score: 0.36
# box coordinate x,y,w,h: [122.73535252 426.12651587 303.02721427 277.100833  ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 742ms/step
# time: 0.83s
